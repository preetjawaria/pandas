# %% [markdown]
# <a href="https://colab.research.google.com/github/preetjawaria/pandas/blob/main/pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dict1 ={'Name':['Priyang','Aadhya','Krisha','Vedant','Parshv',
                'Mittal','Archana'],
                'Marks':[98,89,99,87,90,None,99],
                'Gender':['Male','Female',None,'Male','Male',
                         'Female','Female']
               }

# %%
df1=pd.DataFrame(dict1)

# %%
df1
# Out:
#       Name  Marks  Gender
# 0  Priyang   98.0    Male
# 1   Aadhya   89.0  Female
# 2   Krisha   99.0    None
# 3   Vedant   87.0    Male
# 4   Parshv   90.0    Male
# 5   Mittal    NaN  Female
# 6  Archana   99.0  Female

# %% [markdown]
# **1. Display Top 3 rows of Dataset**

# %%
df1.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang   98.0    Male
# 1   Aadhya   89.0  Female
# 2   Krisha   99.0    None

# %% [markdown]
# **2. Last 3 rows of the Dataset**

# %%
df1.tail(3)
# Out:
#       Name  Marks  Gender
# 4   Parshv   90.0    Male
# 5   Mittal    NaN  Female
# 6  Archana   99.0  Female

# %% [markdown]
# **3. Find Shape of the Dataset**

# %%
df1.shape
# Out:
# (7, 3)

# %%
print("Number of rows in the df1 : ",df1.shape[0])
# Out:
# Number of rows in the df1 :  7

# %% [markdown]
# **4. Get information about the Dataset**

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   6 non-null      float64
#  2   Gender  6 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 300.0+ bytes

# %% [markdown]
# **5. Check Null Values in the Dataset**

# %%
df1.isnull()
# Out:
#     Name  Marks  Gender
# 0  False  False   False
# 1  False  False   False
# 2  False  False    True
# 3  False  False   False
# 4  False  False   False
# 5  False   True   False
# 6  False  False   False

# %%
df1.isnull().sum()
# Out:
# Name      0
# Marks     1
# Gender    1
# dtype: int64

# %%
df1.isnull().sum(axis=0)
# Out:
# Name      0
# Marks     1
# Gender    1
# dtype: int64

# %%
df1.isnull().sum(axis=1)
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# 5    1
# 6    0
# dtype: int64

# %% [markdown]
# **6. Get Overall Statistics about the Dataset**

# %%
df1.describe()
# Out:
#            Marks
# count   6.000000
# mean   93.666667
# std     5.573748
# min    87.000000
# 25%    89.250000
# 50%    94.000000
# 75%    98.750000
# max    99.000000

# %%
df1.describe(include='all')
# Out:
#            Name      Marks Gender
# count         7   6.000000      6
# unique        7        NaN      2
# top     Priyang        NaN   Male
# freq          1        NaN      3
# mean        NaN  93.666667    NaN
# std         NaN   5.573748    NaN
# min         NaN  87.000000    NaN
# 25%         NaN  89.250000    NaN
# 50%         NaN  94.000000    NaN
# 75%         NaN  98.750000    NaN
# max         NaN  99.000000    NaN

# %% [markdown]
# **7. Find Unique values from Gender Column.**

# %%
df1['Gender'].unique()
# Out:
# array(['Male', 'Female', None], dtype=object)

# %% [markdown]
# 8.Find the **number of unique values** from Gender Column.

# %%
df1['Gender'].nunique()
# Out:
# 2

# %% [markdown]
# **9. Count of unique values in Gender Column.**

# %%
df1['Gender'].value_counts()
# Out:
# Gender
# Male      3
# Female    3
# Name: count, dtype: int64

# %% [markdown]
# **10. Find total number of students having marks between 90 & 100 (both inclusive) using between method.**

# %%
df1['Marks']
# Out:
# 0    98.0
# 1    89.0
# 2    99.0
# 3    87.0
# 4    90.0
# 5     NaN
# 6    99.0
# Name: Marks, dtype: float64

# %%
df1['Marks']>=90
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# Name: Marks, dtype: bool

# %%
df1[df1['Marks']>=90]
# Out:
#       Name  Marks  Gender
# 0  Priyang   98.0    Male
# 2   Krisha   99.0    None
# 4   Parshv   90.0    Male
# 6  Archana   99.0  Female

# %%
(df1['Marks']>=90) & (df1['Marks']<=100)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# Name: Marks, dtype: bool

# %%
df1[(df1['Marks']>=90) & (df1['Marks']<=100)]
# Out:
#       Name  Marks  Gender
# 0  Priyang   98.0    Male
# 2   Krisha   99.0    None
# 4   Parshv   90.0    Male
# 6  Archana   99.0  Female

# %%
len(df1[(df1['Marks']>=90) & (df1['Marks']<=100)])
# Out:
# 4

# %%
df1['Marks'].between(90,100)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# Name: Marks, dtype: bool

# %%
df1[df1['Marks'].between(90,100)]
# Out:
#       Name  Marks  Gender
# 0  Priyang   98.0    Male
# 2   Krisha   99.0    None
# 4   Parshv   90.0    Male
# 6  Archana   99.0  Female

# %%
len(df1[df1['Marks'].between(90,100)])
# Out:
# 4

# %%
sum(df1['Marks'].between(90,100))
# Out:
# 4

# %% [markdown]
# **11. Average Marks**

# %%
df1['Marks'].mean()
# Out:
# np.float64(93.66666666666667)

# %% [markdown]
# **12. Apply Method**

# %%
def half_marks(x):
  return x//2

# %%
df1['Marks'].apply(half_marks)
# Out:
# 0    49.0
# 1    44.0
# 2    49.0
# 3    43.0
# 4    45.0
# 5     NaN
# 6    49.0
# Name: Marks, dtype: float64

# %%
df1['Marks'].apply(lambda x:x//2)
# Out:
# 0    49.0
# 1    44.0
# 2    49.0
# 3    43.0
# 4    45.0
# 5     NaN
# 6    49.0
# Name: Marks, dtype: float64

# %%
df1['h_marks']=df1['Marks'].apply(lambda x:x//2)

# %%
df1
# Out:
#       Name  Marks  Gender  h_marks
# 0  Priyang   98.0    Male     49.0
# 1   Aadhya   89.0  Female     44.0
# 2   Krisha   99.0    None     49.0
# 3   Vedant   87.0    Male     43.0
# 4   Parshv   90.0    Male     45.0
# 5   Mittal    NaN  Female      NaN
# 6  Archana   99.0  Female     49.0

# %%
df1['Name'].apply(len)
# Out:
# 0    7
# 1    6
# 2    6
# 3    6
# 4    6
# 5    6
# 6    7
# Name: Name, dtype: int64

# %% [markdown]
# **13. Map Function**

# %%
df1['Gender'].map({'Male':1,'Female':0})
# Out:
# 0    1.0
# 1    0.0
# 2    NaN
# 3    1.0
# 4    1.0
# 5    0.0
# 6    0.0
# Name: Gender, dtype: float64

# %%
df1['M_F'] = df1['Gender'].map({'Male':1,'Female':0})

# %%
df1
# Out:
#       Name  Marks  Gender  h_marks  M_F
# 0  Priyang   98.0    Male     49.0  1.0
# 1   Aadhya   89.0  Female     44.0  0.0
# 2   Krisha   99.0    None     49.0  NaN
# 3   Vedant   87.0    Male     43.0  1.0
# 4   Parshv   90.0    Male     45.0  1.0
# 5   Mittal    NaN  Female      NaN  0.0
# 6  Archana   99.0  Female     49.0  0.0

# %% [markdown]
# **14. Drop the columns**

# %%
df1.drop(['h_marks','M_F'],axis=1)
# Out:
#       Name  Marks  Gender
# 0  Priyang   98.0    Male
# 1   Aadhya   89.0  Female
# 2   Krisha   99.0    None
# 3   Vedant   87.0    Male
# 4   Parshv   90.0    Male
# 5   Mittal    NaN  Female
# 6  Archana   99.0  Female

# %%
df1
# Out:
#       Name  Marks  Gender  h_marks  M_F
# 0  Priyang   98.0    Male     49.0  1.0
# 1   Aadhya   89.0  Female     44.0  0.0
# 2   Krisha   99.0    None     49.0  NaN
# 3   Vedant   87.0    Male     43.0  1.0
# 4   Parshv   90.0    Male     45.0  1.0
# 5   Mittal    NaN  Female      NaN  0.0
# 6  Archana   99.0  Female     49.0  0.0

# %%
df1.drop(['h_marks','M_F'],axis=1,inplace=True)

# %%
df1
# Out:
#       Name  Marks  Gender
# 0  Priyang   98.0    Male
# 1   Aadhya   89.0  Female
# 2   Krisha   99.0    None
# 3   Vedant   87.0    Male
# 4   Parshv   90.0    Male
# 5   Mittal    NaN  Female
# 6  Archana   99.0  Female

# %% [markdown]
# **15. Print Names of the columns**

# %%
df1.columns
# Out:
# Index(['Name', 'Marks', 'Gender'], dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# **16. Sort Dataframe as per the Marks Column.**

# %%
df1.sort_values(by='Marks')
# Out:
#       Name  Marks  Gender
# 3   Vedant   87.0    Male
# 1   Aadhya   89.0  Female
# 4   Parshv   90.0    Male
# 0  Priyang   98.0    Male
# 2   Krisha   99.0    None
# 6  Archana   99.0  Female
# 5   Mittal    NaN  Female

# %%
df1.sort_values(by='Marks',ascending=False)
# Out:
#       Name  Marks  Gender
# 6  Archana   99.0  Female
# 2   Krisha   99.0    None
# 0  Priyang   98.0    Male
# 4   Parshv   90.0    Male
# 1   Aadhya   89.0  Female
# 3   Vedant   87.0    Male
# 5   Mittal    NaN  Female

# %%
df1.sort_values(by=['Marks','Gender'],ascending=False)
# Out:
#       Name  Marks  Gender
# 6  Archana   99.0  Female
# 2   Krisha   99.0    None
# 0  Priyang   98.0    Male
# 4   Parshv   90.0    Male
# 1   Aadhya   89.0  Female
# 3   Vedant   87.0    Male
# 5   Mittal    NaN  Female

# %% [markdown]
# **17. Display Name and Marks of Female students only.**

# %%
df1['Gender']=='Female'
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# Name: Gender, dtype: bool

# %%
df1[df1['Gender']=='Female']
# Out:
#       Name  Marks  Gender
# 1   Aadhya   89.0  Female
# 5   Mittal    NaN  Female
# 6  Archana   99.0  Female

# %%
df1[df1['Gender']=='Female'][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya   89.0
# 5   Mittal    NaN
# 6  Archana   99.0

# %%
df1['Gender'].isin(['Female'])
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# Name: Gender, dtype: bool

# %%
df1[df1['Gender'].isin(['Female'])]
# Out:
#       Name  Marks  Gender
# 1   Aadhya   89.0  Female
# 5   Mittal    NaN  Female
# 6  Archana   99.0  Female

# %%
df1[df1['Gender'].isin(['Female'])][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya   89.0
# 5   Mittal    NaN
# 6  Archana   99.0
